# %% [markdown]
# <a href="https://colab.research.google.com/github/EdjeElectronics/Train-and-Deploy-YOLO-Models/blob/main/Train_YOLO_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Train YOLO Models in Google Colab
# **Author:** Evan Juras, [EJ Technology Consultants](https://ejtech.io)
#
# **Last updated:** January 3, 2025
#
# **GitHub:** [Train and Deploy YOLO Models](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models)
#
# # Introduction
#
# This notebook uses [Ultralytics](https://docs.ultralytics.com/) to train YOLO11, YOLOv8, or YOLOv5 object detection models with a custom dataset. At the end of this Colab, you'll have a custom YOLO model that you can run on your PC, phone, or edge device like the Raspberry Pi.
#
# <p align=center>
# <img src="https://s3.us-west-1.amazonaws.com/evanjuras.com/img/yolo-model-demo.gif" height="360"><br>
# <i>Custom YOLO candy detection model in action!</i>
# </p>
#
# I created a YouTube video that walks through this guide step by step. I recommend following along with the video while working through this notebook.
#
# <p align=center>
# <a href="https://youtu.be/r0RspiLG260" target="_blank"><img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/Train_YOLO_Thumbnail2.png" height="240"><br>
# <i>Click here to go to the video!</i></a>
# </p>
#
# **Important note: This notebook will be continuously updated to make sure it works with newer versions of Ultralytics and YOLO. If you see any differences between the YouTube video and this notebook, always follow the notebook!**

# %% [markdown]
# **Verify NVIDIA GPU Availability**
#
# Make sure you're using a GPU-equipped machine by going to "Runtime" -> "Change runtime type" in the top menu bar, and then selecting one of the GPU options in the Hardware accelerator section. Click Play on the following code block to verify that the NVIDIA GPU is present and ready for training.

# %%
# !nvidia-smi
# Out:
# Wed Sep 16 21:38:39 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.173.02             Driver Version: 580.173.02     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1660 ...    Off |   00000000:00:11.0 Off |                  N/A |
# | 34%   42C    P8             10W /  125W |       9MiB /   6144MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            2026      G   /usr/lib/xorg/Xorg                        4MiB |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# #1.&nbsp;Gather and Label Training Images

# %% [markdown]
# Before we start training, we need to gather and label images that will be used for training the object detection model. A good starting point for a proof-of-concept model is 200 images. The training images should have random objects in the image along with the desired objects, and should have a variety of backgrounds and lighting conditions.
#
# There are a couple options for gathering images:
#
#
# *   Build a custom dataset by taking your own pictures of the objects and labeling them (this typically results in the best performance)
# *   Find a pre-made dataset from sources like [Roboflow Universe](), [Kaggle](), or [Google Images V7]()
#
#
# If you want to build your own dataset, there are several tools available for labeling images. One good option is [Label Studio](https://labelstud.io/?utm_source=youtube&utm_medium=video&utm_campaign=edjeelectronics), a free and open-source labeling tool that has a simple workflow while providing capabilities for more advanced features. My YouTube video that walks through this notebook (link to be added soon) shows how to label images with Label Studio.
#
# <p align=center>
# <img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/label-studio-example.PNG" height="380"><br>
# <i>Example of a candy image labeled with Label Studio.</i>
# </p>
#
# If you used Label Studio to label and export the images, they'll be exported in a `project.zip` file that contains the following:
#
# - An `images` folder containing the images
# - A `labels` folder containing the labels in YOLO annotation format
# - A `classes.txt` labelmap file that contains all the classes
# - A `notes.json` file that contains info specific to Label Studio (this file can be ignored)
#
# If you obtained your dataset from another source (like Roboflow Universe) or used another tool to label your dataset, make sure the files are organized in the same folder structure.
#
# <p align=center>
# <img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/zipped-data-example.png" height=""><br>
# <i>Organize your data in the folders shown here. See my <a href="https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/candy_data_06JAN25.zip">Candy Detection Dataset</a> for an example.</i>
# </p>
#
# Once you've got your dataset built, put into the file structure shown above, and zipped into `data.zip`, you're ready to move on to the next step.

# %% [markdown]
# # 2.&nbsp;Upload Image Dataset and Prepare Training Data

# %% [markdown]
# Next, we'll upload our dataset and prepare it for training with YOLO. We'll split the dataset into train and validation folders, and we'll automatically generate the configuration file for training the model.

# %% [markdown]
# ## 2.1 Split images into train and validation folders

# %% [markdown]
# Next, we'll unzip `data.zip` and create some folders to hold the images. Run the following code block to unzip the data.

# %% [markdown]
# Ultralytics requires a particular folder structure to store training data for models. Ultralytics requires a particular folder structure to store training data for models. The root folder is named “data”. Inside, there are two main folders:
#
# *   **Train**: These are the actual images used to train the model. In one epoch of training, every image in the train set is passed into the neural network. The training algorithm adjusts the network weights to fit the data in the images.
#
#
# *   **Validation**: These images are used to check the model's performance at the end of each training epoch.
#
# In each of these folders is a “images” folder and a “labels” folder, which hold the image files and annotation files respectively.

# %% [markdown]
# I wrote a Python script that will automatically create the required folder structure and randomly move 90% of dataset to the "train" folder and 10% to the "validation" folder. Run the following code block to download and execute the scrpt.

# %%
# !wget -O ./train_val_split.py https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/utils/train_val_split.py
# Out:
# --2026-09-17 16:02:24--  https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/utils/train_val_split.py
# Risoluzione di raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connessione a raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connesso.
# Richiesta HTTP inviata, in attesa di risposta... 200 OK
# Lunghezza: 3203 (3,1K) [text/plain]
# Salvataggio in: ‘./train_val_split.py’
#
# ./train_val_split.p 100%[===================>]   3,13K  --.-KB/s    in 0s
#
# 2026-09-17 16:02:24 (39,7 MB/s) - ‘./train_val_split.py’ salvato [3203/3203]

# %%
# TO DO: Improve robustness of train_val_split.py script so it can handle nested data folders, etc
# !python train_val_split.py --datapath="./dati_di_input_rete" --train_pct=0.9
# Out:
# Created folder at /home/jago.camoni.STUDENTI/Documenti/HoloOceanLibrary/src/rete_custom/rete_custom_shapes/data/train/images.
# Created folder at /home/jago.camoni.STUDENTI/Documenti/HoloOceanLibrary/src/rete_custom/rete_custom_shapes/data/train/labels.
# Created folder at /home/jago.camoni.STUDENTI/Documenti/HoloOceanLibrary/src/rete_custom/rete_custom_shapes/data/validation/images.
# Created folder at /home/jago.camoni.STUDENTI/Documenti/HoloOceanLibrary/src/rete_custom/rete_custom_shapes/data/validation/labels.
# Number of image files: 41
# Number of annotation files: 41
# Images moving to train: 36
# Images moving to validation: 5

# %% [markdown]
# # 3.&nbsp;Install Requirements (Ultralytics)
#
# Next, we'll install the Ultralytics library. This Python library will be used to train the YOLO model.

# %%
# %pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (8.4.75)
# Requirement already satisfied: numpy>=1.23.0 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from ultralytics) (3.10.9)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from ultralytics) (12.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from ultralytics) (2.12.1)
# Requirement already satisfied: torchvision>=0.9.0 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from ultralytics) (0.27.1)
# Requirement already satisfied: psutil>=5.8.0 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from ultralytics) (7.2.2)
# Requirement already satisfied: polars>=0.20.0 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from ultralytics) (1.41.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from ultralytics) (13.610.43)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from ultralytics) (2.0.20)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (26.0)
# Requirement already satisfied: pyparsing>=3 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.41.2 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from polars>=0.20.0->ultralytics) (1.41.2)
# Requirement already satisfied: six>=1.5 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2026.6.17)
# Requirement already satisfied: filelock in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.29.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools<82 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2026.6.0)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics) (13.0.2)
# Requirement already satisfied: nvidia-cublas<=13.1.1.3,>=13.1.0.3 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (13.1.1.3)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (13.3.1)
# Requirement already satisfied: nvidia-cudnn-cu13==9.20.0.48 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (9.20.0.48)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.1 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (0.8.1)
# Requirement already satisfied: nvidia-nccl-cu13==2.29.7 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2.29.7)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.4.5)
# Requirement already satisfied: triton==3.7.1 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.7.1)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics) (10.4.0.35)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics) (13.0.85)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics) (13.0.88)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.0.4.66)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics) (13.0.96)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics) (1.15.1.6)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics) (13.0.88)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.0.0.61)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics) (13.0.85)
# Requirement already satisfied: cuda-pathfinder>=1.4.2 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from cuda-bindings<14,>=13.0.3->torch>=1.8.0->ultralytics) (1.5.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jago.camoni.STUDENTI/miniconda3/envs/train_images_0/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 4.&nbsp;Configure Training

# %% [markdown]
# There's one last step before we can run training: we need to create the Ultralytics training configuration YAML file. This file specifies the location of your train and validation data, and it also defines the model's classes. An example configuration file model is available [here](https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/datasets/coco128.yaml).
#
# Run the code block below to automatically generate a `data.yaml` configuration file. Make sure you have a labelmap file located at `custom_data/classes.txt`. If you used Label Studio or one of my pre-made datasets, it should already be present. If you assembled the dataset another way, you may have to manually create the `classes.txt` file (see [here](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/blob/main/doc/classes.txt) for an example of how it's formatted).

# %%
# Python function to automatically create data.yaml config file
# 1. Reads "classes.txt" file to get list of class names
# 2. Creates data dictionary with correct paths to folders, number of classes, and names of classes
# 3. Writes data in YAML format to data.yaml

import yaml
import os

def create_data_yaml(path_to_classes_txt, path_to_data_yaml):

  # Read class.txt to get class names
  if not os.path.exists(path_to_classes_txt):
    print(f'classes.txt file not found! Please create a classes.txt labelmap and move it to {path_to_classes_txt}')
    return
  with open(path_to_classes_txt, 'r') as f:
    classes = []
    for line in f.readlines():
      if len(line.strip()) == 0: continue
      classes.append(line.strip())
  number_of_classes = len(classes)

  # Create data dictionary
  data = {
      'path': './data',
      'train': 'train/images',
      'val': 'validation/images',
      'nc': number_of_classes,
      'names': classes
  }

  # Write data to YAML file
  with open(path_to_data_yaml, 'w') as f:
    yaml.dump(data, f, sort_keys=False)
  print(f'Created config file at {path_to_data_yaml}')

  return

# Define path to classes.txt and run function
path_to_classes_txt = './dati_di_input_rete/classes.txt'
path_to_data_yaml = './data.yaml'

create_data_yaml(path_to_classes_txt, path_to_data_yaml)

print('\nFile contents:\n')
# !cat ./data.yaml
# Out:
# Created config file at ./data.yaml
#
# File contents:
#
# path: ./data
# train: train/images
# val: validation/images
# nc: 4
# names:
# - box
# - cone
# - cylinder
# - sphere

# %% [markdown]
# # 5.&nbsp;Train Model

# %% [markdown]
# ## 5.1 Training Parameters
# Now that the data is organized and the config file is created, we're ready to start training! First, there are a few important parameters to decide on. Visit my article on [Training YOLO Models Locally](https://www.ejtech.io/learn/train-yolo-models) to learn more about these parameters and how to choose them.
#
# **Model architecture & size (`model`):**
#
# There are several YOLO11 models sizes available to train, including `yolo11n.pt`, `yolo11s.pt`, `yolo11m.pt`, `yolo11l.pt`, and `yolo11xl.pt`. Larger models run slower but have higher accuracy, while smaller models run faster but have lower accuracy. I made a brief YouTube video that compares performance of different YOLO models on a Raspberry Pi 5 and a laptop with a RTX 4050 GPU, [check it out here to get a sense of their speed accuracy](https://youtu.be/_WKS4E9SmkA). If you aren't sure which model size to use, `yolo11s.pt` is a good starting point.
#
# You can also train YOLOv8 or YOLOv5 models by substituting `yolo11` for `yolov8` or `yolov5`.
#
#
# **Number of epochs (`epochs`)**
#
# In machine learning, one “epoch” is one single pass through the full training dataset. Setting the number of epochs dictates how long the model will train for. The best amount of epochs to use depends on the size of the dataset and the model architecture. If your dataset has less than 200 images, a good starting point is 60 epochs. If your dataset has more than 200 images, a good starting point is 40 epochs.
#
#
# **Resolution (`imgsz`)**
#
# Resolution has a large impact on the speed and accuracy of the model: a lower resolution model will have higher speed but less accuracy. YOLO models are typically trained and inferenced at a 640x640 resolution. However, if you want your model to run faster or know you will be working with low-resolution images, try using a lower resolution like 480x480.

# %% [markdown]
# ## 5.2 Run Training!

# %% [markdown]
# Run the following code block to begin training. If you want to use a different model, number of epochs, or resolution, change `model`, `epochs`, or `imgsz`.

# %%
# !yolo detect train data=./data.yaml model=yolo26n.pt epochs=60 imgsz=640
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 40.0MB/s 0.1s.1s<0.1s
# New https://pypi.org/project/ultralytics/8.4.154 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.75 🚀 Python-3.10.20 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce GTX 1660 SUPER, 5747MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=./data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=60, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/jago.camoni.STUDENTI/Documenti/HoloOceanLibrary/src/rete_custom/rete_custom_shapes/runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1
640: 100% ━━━━━━━━━━━━ 3/3 4.0it/s 0.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 21.4it/s 0.0s
#                    all          5         42       0.69      0.541      0.667      0.446
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/60      4.65G      1.431      2.095   0.006973         62        640: 100% ━━━━━━━━━━━━ 3/3 3.9it/s 0.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 21.3it/s 0.0s
#                    all          5         42      0.696      0.568      0.673       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/60      4.69G      1.481      2.109    0.00554         84        640: 100% ━━━━━━━━━━━━ 3/3 3.9it/s 0.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 22.0it/s 0.0s
#                    all          5         42      0.696      0.568      0.673       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/60      4.54G      1.253      2.111    0.00757         32        640: 100% ━━━━━━━━━━━━ 3/3 4.0it/s 0.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 23.2it/s 0.0s
#                    all          5         42      0.653      0.566      0.675       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/60      4.54G      1.313      1.931   0.006325         71        640: 100% ━━━━━━━━━━━━ 3/3 3.9it/s 0.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 22.3it/s 0.0s
#                    all          5         42      0.665      0.641      0.664      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/60      4.63G       1.36      1.958   0.005689         93        640: 100% ━━━━━━━━━━━━ 3/3 3.8it/s 0.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 23.8it/s 0.0s
#                    all          5         42      0.622      0.645      0.665       0.43
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/60      4.62G      1.285      1.973   0.006917         49        640: 100% ━━━━━━━━━━━━ 3/3 4.0it/s 0.7s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 19.7it/s 0.1s
#                    all          5         42      0.622      0.645      0.665       0.43
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/60      4.63G      1.396      1.891   0.005525        121        640: 100% ━━━━━━━━━━━━ 3/3 3.9it/s 0.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 23.4it/s 0.0s
#                    all          5         42      0.642      0.611      0.675      0.438
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/60      4.61G      1.335      2.053   0.007098         39        640: 100% ━━━━━━━━━━━━ 3/3 3.9it/s 0.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 22.4it/s 0.0s
#                    all          5         42      0.665      0.593      0.673      0.437
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/60      4.68G      1.467      1.964    0.00622         58        640: 100% ━━━━━━━━━━━━ 3/3 3.9it/s 0.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 22.2it/s 0.0s
#                    all          5         42      0.652      0.574      0.693      0.452
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/60      4.62G      1.338      2.153   0.006872         29        640: 100% ━━━━━━━━━━━━ 3/3 4.0it/s 0.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 22.6it/s 0.0s
#                    all          5         42      0.652      0.574      0.693      0.452
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/60      4.63G      1.313      2.017   0.006786         35        640: 100% ━━━━━━━━━━━━ 3/3 3.9it/s 0.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 23.4it/s 0.0s
#                    all          5         42      0.649      0.569      0.693      0.456
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/60      4.64G      1.442      2.392   0.007023         35        640: 100% ━━━━━━━━━━━━ 3/3 2.9it/s 1.0s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 18.1it/s 0.1s
#                    all          5         42      0.666      0.614      0.705       0.47
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/60      4.62G      1.323      2.085   0.007181         51        640: 100% ━━━━━━━━━━━━ 3/3 4.0it/s 0.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 21.7it/s 0.0s
#                    all          5         42      0.649      0.648      0.701      0.466
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/60      4.65G      1.257       2.24   0.007623         27        640: 100% ━━━━━━━━━━━━ 3/3 4.1it/s 0.7s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 22.0it/s 0.0s
#                    all          5         42      0.649      0.648      0.701      0.466
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/60      4.62G      1.281      2.023   0.007124         44        640: 100% ━━━━━━━━━━━━ 3/3 4.0it/s 0.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 22.5it/s 0.0s
#                    all          5         42      0.665      0.681      0.706      0.465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/60       4.6G       1.24      2.072   0.007549         25        640: 100% ━━━━━━━━━━━━ 3/3 4.0it/s 0.7s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 22.5it/s 0.0s
#                    all          5         42      0.679      0.685      0.714       0.47
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/60      4.65G      1.264      2.095   0.007469         32        640: 100% ━━━━━━━━━━━━ 3/3 4.0it/s 0.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 23.7it/s 0.0s
#                    all          5         42      0.716       0.68      0.702      0.461
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/60      4.65G      1.146      2.139   0.006912         23        640: 100% ━━━━━━━━━━━━ 3/3 4.0it/s 0.7s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 22.1it/s 0.0s
#                    all          5         42      0.716       0.68      0.702      0.461
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/60      4.62G      1.316      1.939   0.008119         44        640: 100% ━━━━━━━━━━━━ 3/3 4.0it/s 0.7s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 21.0it/s 0.0s
#                    all          5         42      0.719      0.662       0.71      0.459
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       59/60       4.6G      1.213      2.057   0.006996         28        640: 100% ━━━━━━━━━━━━ 3/3 4.0it/s 0.7s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 22.2it/s 0.0s
#                    all          5         42      0.713      0.651      0.708      0.456
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       60/60      4.65G      1.288      1.952   0.007586         53        640: 100% ━━━━━━━━━━━━ 3/3 3.9it/s 0.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 21.9it/s 0.0s
#                    all          5         42      0.711      0.647      0.704      0.451
#
# 60 epochs completed in 0.022 hours.
# Optimizer stripped from /home/jago.camoni.STUDENTI/Documenti/HoloOceanLibrary/src/rete_custom/rete_custom_shapes/runs/detect/train/weights/last.pt, 5.4MB
# Optimizer stripped from /home/jago.camoni.STUDENTI/Documenti/HoloOceanLibrary/src/rete_custom/rete_custom_shapes/runs/detect/train/weights/best.pt, 5.4MB
#
# Validating /home/jago.camoni.STUDENTI/Documenti/HoloOceanLibrary/src/rete_custom/rete_custom_shapes/runs/detect/train/weights/best.pt...
# Ultralytics 8.4.75 🚀 Python-3.10.20 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce GTX 1660 SUPER, 5747MiB)
# YOLO26n summary (fused): 122 layers, 2,375,616 parameters, 0 gradients, 5.2 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 36.9it/s 0.0s
#                    all          5         42      0.666      0.614      0.705       0.47
#                    box          4         14      0.816      0.634      0.815      0.546
#                   cone          4          6      0.763      0.667      0.739      0.454
#               cylinder          4         10      0.318        0.6      0.471      0.317
#                 sphere          5         12      0.769      0.556      0.794      0.563
# Speed: 0.2ms preprocess, 3.2ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /home/jago.camoni.STUDENTI/Documenti/HoloOceanLibrary/src/rete_custom/rete_custom_shapes/runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# The training algorithm will parse the images in the training and validation directories and then start training the model. At the end of each training epoch, the program runs the model on the validation dataset and reports the resulting mAP, precision, and recall. As training continues, the mAP should generally increase with each epoch. Training will end once it goes through the number of epochs specified by `epochs`.
#
# > **NOTE:** Make sure to allow training to run to completion, because an optimizer runs at the end of training that strips out unneeded layers from the model.
#
# The best trained model weights will be saved in `content/runs/detect/train/weights/best.pt`. Additional information about training is saved in the `content/runs/detect/train` folder, including a `results.png` file that shows how loss, precision, recall, and mAP progressed over each epoch.

# %% [markdown]
# ## 6 Test Model

# %% [markdown]
# The model has been trained; now it's time to test it! The commands below run the model on the images in the validation folder and then display the results for the first 10 images. This is a good way to confirm your model is working as expected. Click Play on the blocks below to see how your model performs.

# %%
# !yolo detect predict model=runs/detect/train/weights/best.pt source=data/validation/images save=True
# Out:
# Ultralytics 8.4.75 🚀 Python-3.10.20 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce GTX 1660 SUPER, 5747MiB)
# YOLO26n summary (fused): 122 layers, 2,375,616 parameters, 0 gradients, 5.2 GFLOPs
#
# image 1/5 /home/jago.camoni.STUDENTI/Documenti/HoloOceanLibrary/src/rete_custom/rete_custom_shapes/data/validation/images/1084e984-foto_1789577321560.png: 480x640 (no detections), 34.9ms
# image 2/5 /home/jago.camoni.STUDENTI/Documenti/HoloOceanLibrary/src/rete_custom/rete_custom_shapes/data/validation/images/1299230b-foto_1789576549160.png: 480x640 1 cone, 1 cylinder, 8.4ms
# image 3/5 /home/jago.camoni.STUDENTI/Documenti/HoloOceanLibrary/src/rete_custom/rete_custom_shapes/data/validation/images/9213bd3e-foto_1789576444062.png: 480x640 1 cylinder, 1 sphere, 8.3ms
# image 4/5 /home/jago.camoni.STUDENTI/Documenti/HoloOceanLibrary/src/rete_custom/rete_custom_shapes/data/validation/images/9aaac14b-foto_1789576874978.png: 480x640 1 box, 2 cylinders, 2 spheres, 7.6ms
# image 5/5 /home/jago.camoni.STUDENTI/Documenti/HoloOceanLibrary/src/rete_custom/rete_custom_shapes/data/validation/images/d34cbfb8-foto_1789576440932.png: 480x640 1 cone, 1 sphere, 7.9ms
# Speed: 1.1ms preprocess, 13.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to /home/jago.camoni.STUDENTI/Documenti/HoloOceanLibrary/src/rete_custom/rete_custom_shapes/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import glob
from IPython.display import Image, display
for image_path in glob.glob(f'./runs/detect/predict/*.jpg')[:10]:
  display(Image(filename=image_path, height=400))
  print('\n')

# %% [markdown]
# The model should draw a box around each object of interest in each image. If it isn't doing a good job of detecting objects, here are a few tips:
#
# 1. Double-check your dataset to make sure there are no labeling errors or conflicting examples.
# 2. Increase the number of epochs used for training.
# 3. Use a larger model size (e.g. `yolo11l.pt`).
# 4. Add more images to the training dataset. See my [dataset video](https://www.youtube.com/watch?v=v0ssiOY6cfg) for tips on how to capture good training images and improve accuracy.
#
# You can also run the model on video files or other images images by uploading them to this notebook and using the above `!yolo detect predict` command, where `source` points to the location of the video file, image, or folder of images. The results will be saved in `runs/detect/predict`.
#
# Drawing boxes on images is great, but it isn't very useful in itself. It's also not very helpful to just run this models inside a Colab notebook: it's easier if we can just run it on a local computer. Continue to the next section to see how to download your newly trained model and run it on a local device.

# %% [markdown]
# #7.&nbsp;Deploy Model

# %% [markdown]
# Now that your custom model has been trained, it's ready to be downloaded and deployed in an application! YOLO models can run on a wide variety of hardware, including PCs, embedded systems, and phones. Ultralytics makes it easy to convert the YOLO models to various formats (`tflite`, `onnx`, etc.) and deploy them in a variety of environments.
#
# This section shows how to download the model and provides links to instructions for deploying it on your PC and edge devices like the Raspberry Pi.

# %% [markdown]
# ## 7.1 Download YOLO Model
#
# First, zip and download the trained model by running the code blocks below.
#
# The code creates a folder named `my_model`, moves the model weights into it, and renames them from `best.pt` to `my_model.pt`. It also adds the training results in case you want to reference them later. It then zips the folder as `my_model.zip`.

# %%
# Create "my_model" folder to store model weights and train results
# !mkdir ./my_model
# !cp ./runs/detect/train/weights/best.pt ./my_model/my_model.pt
# !cp -r ./runs/detect/train ./my_model

# Zip into "my_model.zip"
# %cd my_model
# !zip ./my_model.zip my_model.pt
# !zip -r ./my_model.zip train
# %cd ./
# Out:
# cp: impossibile eseguire stat di './runs/detect/train/weights/best.pt': File o directory non esistente
# cp: impossibile eseguire stat di './runs/detect/train': File o directory non esistente
# /home/jago.camoni.STUDENTI/Documenti/HoloOceanLibrary/src/rete_custom/rete_custom_shapes/my_model/my_model/my_model/my_model
# 	zip warning: name not matched: my_model.pt
#
# zip error: Nothing to do! (./my_model.zip)
# 	zip warning: name not matched: train
#
# zip error: Nothing to do! (try: zip -r ./my_model.zip . -i train)
# /home/jago.camoni.STUDENTI/Documenti/HoloOceanLibrary/src/rete_custom/rete_custom_shapes/my_model/my_model/my_model/my_model

# %% [markdown]
# ## 7.2 Deploy YOLO Model on Local Devices
#
# Next, we'll take our downloaded model and run it on a local device. This section provides instructions showing how to deploy YOLO models on various devices.
#
# I wrote a basic Python script, `yolo_detect.py`, that shows how to load a model, run inference on an image source, parse the inference results, and display boxes around each detected class in the image. The [script](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/blob/main/yolo_detect.py) gives an example of how to work with Ultralytics YOLO models in Python, and it can be used as a starting point for more advanced applications.

# %% [markdown]
# ### 7.2.1 Deploy on PC (Windows, Linux, or macOS)
#
# The easiest way to run Ultralytics models on a PC is using Anaconda. Anaconda sets up a virtual Python environment and allows you to easily install Ultralytics and PyTorch. It automatically installs CUDA and cuDNN, which allows you to speed up model inference with your NVIDIA GPU.
#
# > **NOTE:** My YouTube video (link to be added) shows how to deploy your model on a PC. It walks through the following steps, so watch the video if you prefer having visual instructions.
#
# **1. Download and Install Anaconda**
#
# Go to the Anaconda download page at https://anaconda.com/download, click the “skip registration” button, and then download the package for your OS. When it's finished downloading, run the installer and click through the installation steps. You can use the default options for installation.
#
# **2. Set up virtual environment**
#
# Once it's installed, run Anaconda Prompt from the Start Bar. (If you're on macOS or Linux, just open a command terminal).
#
# Issue the following commands to create a new Python environment and activate it:
#
# ```
# conda create --name yolo-env1 python=3.12 -y
# conda activate yolo-env1
# ```
#
# Install Ultralytics (which also installs import libraries like OpenCV-Python, Numpy, and PyTorch) by issuing the following command:
#
# ```
# pip install ultralytics
# ```
#
# If you have an NVIDIA GPU, you can install the GPU-enabled version of PyTorch by issuing the following command:
#
# ```
# pip install --upgrade torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124
# ```
#
# **3. Extract downloaded model**
# Take the `my_model.zip` file you downloaded in Step 7.1 and unzip it to a folder on your PC. In the Anaconda Prompt terminal, move into the unzipped folder using:
#
# ```
# cd path/to/folder
# ```
#
# **4. Download and run yolo_detect.py**
#
# Download the `yolo_detect.py` script into the `my_model` folder using:
#
# ```
# curl -o yolo_detect.py https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/yolo_detect.py
# ```
#
# Alright! We're ready to run the script. To run inference with a yolov8s model on a USB camera at 1280x720 resolution, issue:
#
# ```
# python yolo_detect.py --model my_model.pt --source usb0 --resolution 1280x720
# ```
#
# A window will appear showing a live feed from your webcam with boxes drawn around detected objects in each frame.
#
# You can also run the model on an video file, image, or folder of images. To see a full list of arguments for `yolo_detect.py`, issue `python yolo_detect.py --help` or see the [README file](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/blob/main/README.md).

# %% [markdown]
# ### 7.2.2 Deploy on Raspberry Pi
#
# Keep an eye out for an article showing how to convert YOLO models to NCNN format and run them on the Raspberry Pi!

# %% [markdown]
# # 8.&nbsp;Conclusion

# %% [markdown]
# Congratulations! You've successfully trained and deployed a YOLO object detection model. 😀
#
# Next, you can extend your application beyond just drawing boxes and counting objects. Add functionality like logging the number of objects detected over time or taking a picture when certain objects are detected. Check out some example applications at our GitHub repository: https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models
#
# Thanks for working through this notebook, and good luck with your projects!

# %% [markdown]
# # Appendix: Common Errors

# %% [markdown]
# If you run into any errors working through this notebook, please do the following:
#
#
# - Double-check that the dataset files are set up in the correct folder structure
# - Make sure there are no typos or errors in your labelmap file
# - Google search the error to look for solutions
#
# If none of those help, please submit an [Issue](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/issues) on the GitHub page. In this section, I will add resolutions to common errors as they come up.
